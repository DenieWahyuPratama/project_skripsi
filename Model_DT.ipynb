# %% [markdown]
# # Permodelan decision tree

# %% [markdown]
# import dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv('/content/drive/MyDrive/skripsi/response_dataset.csv')
df

# %%
y = df.iloc[:,1]
x = df.drop(['status','url'], axis=1)
x

# %%
y

# %% [markdown]
# Classification DT

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc_x = StandardScaler()
#x_train = sc_x.fit_transform(x_train)
#x_test = sc_x.fit_transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,accuracy_score
classifier = DecisionTreeClassifier(random_state =0)
classifier.fit(x_train,y_train)
y_predict = classifier.predict(x_test)
accuracy_score(y_test,y_predict)

# %%
x_train

# %% [markdown]
# Save model pickle

# %%
import pickle

with open('classifier.pkl', 'wb') as file:
    pickle.dump(classifier, file)

# %% [markdown]
# Visualisasi model

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.rcParams['figure.dpi'] = 100
plt.subplots(figsize=(20,30))
tree.plot_tree(classifier, fontsize=10)
plt.show()

# %% [markdown]
# Evaluasi model

# %%
from sklearn.metrics import classification_report

y_predict = classifier.predict(x_test)

print(classification_report(y_test,y_predict))

# %% [markdown]
# Pengujian

# %%
uji = df.iloc[5]
#uji[60]
#classifier.predict(uji[2:].values.reshape(1,-1))

tes = uji[2:].values.reshape(1,-1)
tes

# %% [markdown]
# Performance analysis

# %%
cm = confusion_matrix(y_test, y_predict)

plt.figure(figsize=(5,5))
sn.heatmap(cm, annot=True)

# %%
ac = accuracy_score(y_test,y_predict)
ac = ac * 100
ac

# %% [markdown]
# Visualiasi tree

# %%
from sklearn.tree import export_graphviz

export_graphviz(classifier, out_file="data.dot", filled=True, rounded=True, special_characters=True, feature_names =x.columns, class_names=['0','1'])

# %%
import graphviz

with open('data.dot') as fig:
  dot_graph = fig.read()
graphviz.Source(dot_graph)

# %%
from subprocess import call
call(['dot', '-Tpng', 'data.dot', '-o', 'data.png', '-Gdpi=600'])

# %%
from IPython.display import Image
Image(filename = 'data.png')
